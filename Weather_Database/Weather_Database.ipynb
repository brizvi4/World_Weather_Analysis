# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 740

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | salalah
# Processing Record 4 of Set 1 | rio grande
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | pitimbu
# Processing Record 7 of Set 1 | sambava
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | kutum
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | najran
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | kirakira
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | meridian
# Processing Record 18 of Set 1 | dauphin
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | saint-joseph
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | rapid valley
# Processing Record 26 of Set 1 | namatanai
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | kijang
# Processing Record 29 of Set 1 | verkhoyansk
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | bay roberts
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | dawei
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | codrington
# Processing Record 37 of Set 1 | sanghar
# Processing Record 38 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 1 | hofn
# Processing Record 40 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 1 | vestmanna
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | korla
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | carbonia
# Processing Record 3 of Set 2 | havoysund
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | mount isa
# Processing Record 7 of Set 2 | porto recanati
# Processing Record 8 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | hobyo
# Processing Record 11 of Set 2 | necochea
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | mehran
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | cuiluan
# Processing Record 16 of Set 2 | conceicao do araguaia
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | gaildorf
# Processing Record 19 of Set 2 | zuenoula
# Processing Record 20 of Set 2 | luganville
# Processing Record 21 of Set 2 | saldanha
# Processing Record 22 of Set 2 | thinadhoo
# Processing Record 23 of Set 2 | mehamn
# Processing Record 24 of Set 2 | melivoia
# Processing Record 25 of Set 2 | cap-aux-meules
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | ohara
# Processing Record 28 of Set 2 | kenai
# Processing Record 29 of Set 2 | arbuzynka
# Processing Record 30 of Set 2 | aksarka
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | tancitaro
# Processing Record 33 of Set 2 | tilichiki
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 2 | bacolod
# Processing Record 37 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | santiago de cuba
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | meiganga
# Processing Record 42 of Set 2 | micheweni
# Processing Record 43 of Set 2 | xuddur
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | dombarovskiy
# Processing Record 47 of Set 2 | mutis
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | turukhansk
# Processing Record 3 of Set 3 | kisangani
# Processing Record 4 of Set 3 | velsen
# Processing Record 5 of Set 3 | tondano
# Processing Record 6 of Set 3 | okhotsk
# Processing Record 7 of Set 3 | maymyo
# Processing Record 8 of Set 3 | daru
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | haines junction
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | isparta
# Processing Record 15 of Set 3 | tuatapere
# Processing Record 16 of Set 3 | ust-shonosha
# Processing Record 17 of Set 3 | bogorodskoye
# Processing Record 18 of Set 3 | tocache
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | maniitsoq
# Processing Record 21 of Set 3 | surman
# Processing Record 22 of Set 3 | tocopilla
# Processing Record 23 of Set 3 | kavieng
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | cravo norte
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | kahului
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | ippy
# Processing Record 33 of Set 3 | minab
# Processing Record 34 of Set 3 | sidi qasim
# City not found. Skipping...
# Processing Record 35 of Set 3 | sulmona
# Processing Record 36 of Set 3 | erenhot
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | moerai
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | duz
# City not found. Skipping...
# Processing Record 42 of Set 3 | ekhabi
# Processing Record 43 of Set 3 | saint-augustin
# Processing Record 44 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 3 | tumpat
# Processing Record 46 of Set 3 | high rock
# Processing Record 47 of Set 3 | honiara
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | bandarbeyla
# Processing Record 2 of Set 4 | blieskastel
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | mahudha
# Processing Record 6 of Set 4 | moramanga
# Processing Record 7 of Set 4 | saint-pierre
# Processing Record 8 of Set 4 | yarada
# Processing Record 9 of Set 4 | lugoba
# Processing Record 10 of Set 4 | fortuna
# Processing Record 11 of Set 4 | sampit
# Processing Record 12 of Set 4 | meulaboh
# Processing Record 13 of Set 4 | robore
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | sosnovo-ozerskoye
# Processing Record 16 of Set 4 | gloucester
# Processing Record 17 of Set 4 | half moon bay
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | urucara
# Processing Record 20 of Set 4 | laguna
# Processing Record 21 of Set 4 | deputatskiy
# Processing Record 22 of Set 4 | salinopolis
# Processing Record 23 of Set 4 | beringovskiy
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | vardo
# Processing Record 26 of Set 4 | gachancipa
# Processing Record 27 of Set 4 | cairns
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | wellington
# Processing Record 31 of Set 4 | clyde river
# Processing Record 32 of Set 4 | kinsale
# Processing Record 33 of Set 4 | tangerang
# Processing Record 34 of Set 4 | atuona
# Processing Record 35 of Set 4 | tikhvin
# Processing Record 36 of Set 4 | liepaja
# Processing Record 37 of Set 4 | sao geraldo do araguaia
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | isangel
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | vila
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | breytovo
# Processing Record 44 of Set 4 | sarakhs
# Processing Record 45 of Set 4 | rio real
# Processing Record 46 of Set 4 | maues
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 49 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 4 | wanning
# Processing Record 1 of Set 5 | fez
# Processing Record 2 of Set 5 | polyarnyy
# Processing Record 3 of Set 5 | leningradskiy
# Processing Record 4 of Set 5 | alofi
# Processing Record 5 of Set 5 | havre-saint-pierre
# Processing Record 6 of Set 5 | urgut
# Processing Record 7 of Set 5 | manica
# Processing Record 8 of Set 5 | tomatlan
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | lilongwe
# Processing Record 11 of Set 5 | vazante
# Processing Record 12 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 5 | dillon
# Processing Record 14 of Set 5 | borujerd
# Processing Record 15 of Set 5 | sur
# Processing Record 16 of Set 5 | iracoubo
# Processing Record 17 of Set 5 | achacachi
# Processing Record 18 of Set 5 | olinda
# Processing Record 19 of Set 5 | kitob
# Processing Record 20 of Set 5 | san quintin
# Processing Record 21 of Set 5 | aneho
# Processing Record 22 of Set 5 | doka
# Processing Record 23 of Set 5 | san policarpo
# Processing Record 24 of Set 5 | kamskiye polyany
# Processing Record 25 of Set 5 | naryan-mar
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | terney
# Processing Record 29 of Set 5 | pathein
# Processing Record 30 of Set 5 | kitui
# Processing Record 31 of Set 5 | manzil salim
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | salym
# Processing Record 34 of Set 5 | shenzhen
# Processing Record 35 of Set 5 | mecca
# Processing Record 36 of Set 5 | karpuninskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | gisborne
# Processing Record 38 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 5 | solnechnyy
# Processing Record 40 of Set 5 | anadyr
# Processing Record 41 of Set 5 | taltal
# Processing Record 42 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 5 | bataipora
# Processing Record 44 of Set 5 | thio
# Processing Record 45 of Set 5 | bathsheba
# Processing Record 46 of Set 5 | vanimo
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | witu
# Processing Record 49 of Set 5 | udachnyy
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | ossora
# Processing Record 2 of Set 6 | punta de piedra
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | bethanien
# Processing Record 5 of Set 6 | kavaratti
# Processing Record 6 of Set 6 | puerto del rosario
# Processing Record 7 of Set 6 | dikson
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | fort nelson
# Processing Record 10 of Set 6 | manacapuru
# Processing Record 11 of Set 6 | port macquarie
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | knysna
# Processing Record 14 of Set 6 | rocha
# Processing Record 15 of Set 6 | vila franca do campo
# Processing Record 16 of Set 6 | beaverlodge
# Processing Record 17 of Set 6 | yulara
# Processing Record 18 of Set 6 | mitu
# Processing Record 19 of Set 6 | barentu
# Processing Record 20 of Set 6 | saskylakh
# Processing Record 21 of Set 6 | bima
# Processing Record 22 of Set 6 | dunedin
# Processing Record 23 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 6 | carnarvon
# Processing Record 25 of Set 6 | muskegon
# Processing Record 26 of Set 6 | matagami
# Processing Record 27 of Set 6 | clinton
# Processing Record 28 of Set 6 | chokurdakh
# Processing Record 29 of Set 6 | khash
# Processing Record 30 of Set 6 | egvekinot
# Processing Record 31 of Set 6 | el rosario
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | bairiki
# Processing Record 34 of Set 6 | quincy
# Processing Record 35 of Set 6 | caramay
# Processing Record 36 of Set 6 | caravelas
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | asgabat
# Processing Record 39 of Set 6 | chara
# Processing Record 40 of Set 6 | smithers
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | iskateley
# Processing Record 43 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 6 | ibimirim
# Processing Record 46 of Set 6 | altonia
# City not found. Skipping...
# Processing Record 47 of Set 6 | puerto pinasco
# City not found. Skipping...
# Processing Record 48 of Set 6 | yamada
# Processing Record 49 of Set 6 | atka
# City not found. Skipping...
# Processing Record 50 of Set 6 | novyy urengoy
# Processing Record 1 of Set 7 | nyurba
# Processing Record 2 of Set 7 | abha
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | wenling
# Processing Record 5 of Set 7 | keti bandar
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | avarua
# Processing Record 8 of Set 7 | van
# Processing Record 9 of Set 7 | ormond beach
# Processing Record 10 of Set 7 | tooele
# Processing Record 11 of Set 7 | kilindoni
# Processing Record 12 of Set 7 | kaeo
# Processing Record 13 of Set 7 | houlton
# Processing Record 14 of Set 7 | rehoboth
# Processing Record 15 of Set 7 | narsaq
# Processing Record 16 of Set 7 | port blair
# Processing Record 17 of Set 7 | lusambo
# Processing Record 18 of Set 7 | lima
# Processing Record 19 of Set 7 | candelaria
# Processing Record 20 of Set 7 | portland
# Processing Record 21 of Set 7 | bucyrus
# Processing Record 22 of Set 7 | den helder
# Processing Record 23 of Set 7 | santa fe
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 7 | isoka
# Processing Record 27 of Set 7 | walvis bay
# Processing Record 28 of Set 7 | juneau
# Processing Record 29 of Set 7 | byron bay
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 33 of Set 7 | mogadishu
# Processing Record 34 of Set 7 | richards bay
# Processing Record 35 of Set 7 | xichang
# Processing Record 36 of Set 7 | adrar
# Processing Record 37 of Set 7 | cururupu
# Processing Record 38 of Set 7 | tabou
# Processing Record 39 of Set 7 | ahipara
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | touros
# Processing Record 42 of Set 7 | muhos
# Processing Record 43 of Set 7 | diamantino
# Processing Record 44 of Set 7 | perevoz
# Processing Record 45 of Set 7 | luanda
# Processing Record 46 of Set 7 | martapura
# Processing Record 47 of Set 7 | lobito
# Processing Record 48 of Set 7 | topolobampo
# Processing Record 49 of Set 7 | boditi
# Processing Record 50 of Set 7 | ostersund
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | ayagoz
# Processing Record 3 of Set 8 | zgierz
# Processing Record 4 of Set 8 | lakes entrance
# Processing Record 5 of Set 8 | paita
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | tukan
# Processing Record 8 of Set 8 | san rafael
# Processing Record 9 of Set 8 | linxia
# Processing Record 10 of Set 8 | san vicente
# Processing Record 11 of Set 8 | pokosnoye
# Processing Record 12 of Set 8 | rundu
# Processing Record 13 of Set 8 | carauari
# Processing Record 14 of Set 8 | qaqortoq
# Processing Record 15 of Set 8 | vila do maio
# Processing Record 16 of Set 8 | kardymovo
# Processing Record 17 of Set 8 | babina
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | pacific grove
# Processing Record 20 of Set 8 | la sarre
# Processing Record 21 of Set 8 | namtsy
# Processing Record 22 of Set 8 | bengkulu
# Processing Record 23 of Set 8 | constitucion
# Processing Record 24 of Set 8 | axim
# Processing Record 25 of Set 8 | tole
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | phayao
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | sivaki
# Processing Record 30 of Set 8 | vilhena
# Processing Record 31 of Set 8 | buin
# Processing Record 32 of Set 8 | puerto maldonado
# Processing Record 33 of Set 8 | vao
# Processing Record 34 of Set 8 | marawi
# Processing Record 35 of Set 8 | yushu
# Processing Record 36 of Set 8 | ishigaki
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | moose factory
# Processing Record 39 of Set 8 | nanortalik
# Processing Record 40 of Set 8 | iquitos
# Processing Record 41 of Set 8 | skibbereen
# Processing Record 42 of Set 8 | outlook
# Processing Record 43 of Set 8 | nemuro
# Processing Record 44 of Set 8 | kjopsvik
# Processing Record 45 of Set 8 | tucuma
# Processing Record 46 of Set 8 | srednekolymsk
# Processing Record 47 of Set 8 | sedalia
# Processing Record 48 of Set 8 | warwick
# Processing Record 49 of Set 8 | waingapu
# Processing Record 50 of Set 8 | kheralu
# Processing Record 1 of Set 9 | caernarfon
# Processing Record 2 of Set 9 | karratha
# Processing Record 3 of Set 9 | high level
# Processing Record 4 of Set 9 | chibombo
# Processing Record 5 of Set 9 | amberley
# Processing Record 6 of Set 9 | ambam
# Processing Record 7 of Set 9 | dedougou
# Processing Record 8 of Set 9 | baykit
# Processing Record 9 of Set 9 | sao joao da barra
# Processing Record 10 of Set 9 | svetlogorsk
# Processing Record 11 of Set 9 | gomel
# Processing Record 12 of Set 9 | shingu
# Processing Record 13 of Set 9 | filadelfia
# Processing Record 14 of Set 9 | payakumbuh
# Processing Record 15 of Set 9 | svetlyy
# Processing Record 16 of Set 9 | geraldton
# Processing Record 17 of Set 9 | phetchaburi
# Processing Record 18 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 19 of Set 9 | natal
# Processing Record 20 of Set 9 | fatezh
# Processing Record 21 of Set 9 | laramie
# Processing Record 22 of Set 9 | sangar
# Processing Record 23 of Set 9 | cockburn town
# Processing Record 24 of Set 9 | gushi
# Processing Record 25 of Set 9 | luau
# Processing Record 26 of Set 9 | sorsk
# Processing Record 27 of Set 9 | malanje
# Processing Record 28 of Set 9 | sukpak
# Processing Record 29 of Set 9 | morgan city
# Processing Record 30 of Set 9 | nogent-sur-oise
# Processing Record 31 of Set 9 | susangerd
# Processing Record 32 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 33 of Set 9 | baruun-urt
# Processing Record 34 of Set 9 | khasan
# Processing Record 35 of Set 9 | dharchula
# Processing Record 36 of Set 9 | pahrump
# Processing Record 37 of Set 9 | trybukhivtsi
# Processing Record 38 of Set 9 | choix
# Processing Record 39 of Set 9 | ambon
# Processing Record 40 of Set 9 | progreso
# Processing Record 41 of Set 9 | balkanabat
# Processing Record 42 of Set 9 | shangrao
# Processing Record 43 of Set 9 | sola
# Processing Record 44 of Set 9 | bogota
# Processing Record 45 of Set 9 | dalinghe
# City not found. Skipping...
# Processing Record 46 of Set 9 | port hardy
# Processing Record 47 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 48 of Set 9 | yuanping
# Processing Record 49 of Set 9 | kangaba
# Processing Record 50 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 10 | saint anthony
# Processing Record 2 of Set 10 | atambua
# Processing Record 3 of Set 10 | bonavista
# Processing Record 4 of Set 10 | guapi
# Processing Record 5 of Set 10 | xai-xai
# Processing Record 6 of Set 10 | abu dhabi
# Processing Record 7 of Set 10 | tabuk
# Processing Record 8 of Set 10 | gravdal
# Processing Record 9 of Set 10 | oistins
# Processing Record 10 of Set 10 | smidovich
# Processing Record 11 of Set 10 | bilibino
# Processing Record 12 of Set 10 | aljezur
# Processing Record 13 of Set 10 | odweyne
# Processing Record 14 of Set 10 | longonjo
# Processing Record 15 of Set 10 | elizabeth city
# Processing Record 16 of Set 10 | huilong
# Processing Record 17 of Set 10 | marsa matruh
# Processing Record 18 of Set 10 | gizo
# Processing Record 19 of Set 10 | santa cruz
# Processing Record 20 of Set 10 | gurlan
# Processing Record 21 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 10 | brewster
# Processing Record 23 of Set 10 | dinar
# Processing Record 24 of Set 10 | srinivaspur
# Processing Record 25 of Set 10 | bubaque
# Processing Record 26 of Set 10 | barraute
# Processing Record 27 of Set 10 | narasannapeta
# Processing Record 28 of Set 10 | gigmoto
# Processing Record 29 of Set 10 | megion
# Processing Record 30 of Set 10 | evensk
# Processing Record 31 of Set 10 | barstow
# Processing Record 32 of Set 10 | mikumi
# Processing Record 33 of Set 10 | sapa
# Processing Record 34 of Set 10 | balabac
# Processing Record 35 of Set 10 | agarak
# Processing Record 36 of Set 10 | jepelacio
# Processing Record 37 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 10 | gambela
# Processing Record 39 of Set 10 | hirara
# Processing Record 40 of Set 10 | mount gambier
# Processing Record 41 of Set 10 | barmer
# Processing Record 42 of Set 10 | mortka
# Processing Record 43 of Set 10 | kristiansund
# Processing Record 44 of Set 10 | dekar
# Processing Record 45 of Set 10 | lazaro cardenas
# Processing Record 46 of Set 10 | praia da vitoria
# Processing Record 47 of Set 10 | dhidhdhoo
# Processing Record 48 of Set 10 | sao miguel do araguaia
# Processing Record 49 of Set 10 | waddan
# Processing Record 50 of Set 10 | santiago
# Processing Record 1 of Set 11 | skjervoy
# Processing Record 2 of Set 11 | umm kaddadah
# Processing Record 3 of Set 11 | iturama
# Processing Record 4 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 11 | acapulco
# Processing Record 6 of Set 11 | tabas
# Processing Record 7 of Set 11 | brae
# Processing Record 8 of Set 11 | kaohsiung
# Processing Record 9 of Set 11 | yumen
# Processing Record 10 of Set 11 | magadan
# Processing Record 11 of Set 11 | novy jicin
# Processing Record 12 of Set 11 | wajima
# Processing Record 13 of Set 11 | pucallpa
# Processing Record 14 of Set 11 | alekseyevsk
# Processing Record 15 of Set 11 | rawson
# Processing Record 16 of Set 11 | malkangiri
# Processing Record 17 of Set 11 | spirit river
# Processing Record 18 of Set 11 | nicoya
# Processing Record 19 of Set 11 | ust-tsilma
# Processing Record 20 of Set 11 | marica
# Processing Record 21 of Set 11 | wewak
# Processing Record 22 of Set 11 | praia
# Processing Record 23 of Set 11 | allapalli
# Processing Record 24 of Set 11 | lleida
# Processing Record 25 of Set 11 | roseburg
# Processing Record 26 of Set 11 | shakawe
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | whitehorse
# Processing Record 29 of Set 11 | oxford
# Processing Record 30 of Set 11 | marsh harbour
# Processing Record 31 of Set 11 | panna
# Processing Record 32 of Set 11 | barao de melgaco
# Processing Record 33 of Set 11 | mbanza-ngungu
# Processing Record 34 of Set 11 | juba
# Processing Record 35 of Set 11 | cookeville
# Processing Record 36 of Set 11 | kununurra
# Processing Record 37 of Set 11 | lasa
# Processing Record 38 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 11 | gobabis
# Processing Record 40 of Set 11 | voyvozh
# Processing Record 41 of Set 11 | poddorye
# Processing Record 42 of Set 11 | thohoyandou
# Processing Record 43 of Set 11 | pandamatenga
# Processing Record 44 of Set 11 | fukue
# Processing Record 45 of Set 11 | lucapa
# Processing Record 46 of Set 11 | hambantota
# Processing Record 47 of Set 11 | phangnga
# Processing Record 48 of Set 11 | kidal
# Processing Record 49 of Set 11 | gimli
# Processing Record 50 of Set 11 | tahe
# Processing Record 1 of Set 12 | vila velha
# Processing Record 2 of Set 12 | kropotkin
# Processing Record 3 of Set 12 | itarema
# Processing Record 4 of Set 12 | barcelos
# Processing Record 5 of Set 12 | saint-francois
# Processing Record 6 of Set 12 | shu
# Processing Record 7 of Set 12 | sembe
# Processing Record 8 of Set 12 | gua musang
# Processing Record 9 of Set 12 | asau
# Processing Record 10 of Set 12 | sao filipe
# Processing Record 11 of Set 12 | seoul
# Processing Record 12 of Set 12 | ketchikan
# Processing Record 13 of Set 12 | coihaique
# Processing Record 14 of Set 12 | nyimba
# Processing Record 15 of Set 12 | russell
# Processing Record 16 of Set 12 | nadym
# Processing Record 17 of Set 12 | north bend
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | mantua
# Processing Record 20 of Set 12 | krivogastani
# Processing Record 21 of Set 12 | westport
# Processing Record 22 of Set 12 | udon thani
# Processing Record 23 of Set 12 | san jose
# Processing Record 24 of Set 12 | uporovo
# Processing Record 25 of Set 12 | prenzlau
# Processing Record 26 of Set 12 | honningsvag
# Processing Record 27 of Set 12 | arman
# Processing Record 28 of Set 12 | basco
# Processing Record 29 of Set 12 | omsukchan
# Processing Record 30 of Set 12 | waipawa
# Processing Record 31 of Set 12 | kolpashevo
# Processing Record 32 of Set 12 | tazmalt
# Processing Record 33 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 12 | saint-louis
# Processing Record 36 of Set 12 | pemangkat
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | neiafu
# Processing Record 39 of Set 12 | bud
# Processing Record 40 of Set 12 | khani
# Processing Record 41 of Set 12 | qasigiannguit
# Processing Record 42 of Set 12 | anaconda
# Processing Record 43 of Set 12 | kiunga
# Processing Record 44 of Set 12 | mastic beach
# Processing Record 45 of Set 12 | berlevag
# Processing Record 46 of Set 12 | mayo
# Processing Record 47 of Set 12 | grindavik
# Processing Record 48 of Set 12 | castlegar
# Processing Record 49 of Set 12 | burgeo
# Processing Record 50 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 13 | palana
# Processing Record 2 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 13 | mana
# Processing Record 4 of Set 13 | butterworth
# Processing Record 5 of Set 13 | henties bay
# Processing Record 6 of Set 13 | ostrovnoy
# Processing Record 7 of Set 13 | qingdao
# Processing Record 8 of Set 13 | ramhormoz
# Processing Record 9 of Set 13 | porto novo
# Processing Record 10 of Set 13 | buraydah
# Processing Record 11 of Set 13 | dodoma
# Processing Record 12 of Set 13 | leshukonskoye
# Processing Record 13 of Set 13 | cartagena
# Processing Record 14 of Set 13 | samarai
# Processing Record 15 of Set 13 | imabari
# City not found. Skipping...
# Processing Record 16 of Set 13 | padang
# Processing Record 17 of Set 13 | anderson
# Processing Record 18 of Set 13 | kepno
# Processing Record 19 of Set 13 | hovd
# Processing Record 20 of Set 13 | hecelchakan
# Processing Record 21 of Set 13 | lac du bonnet
# Processing Record 22 of Set 13 | itoman
# Processing Record 23 of Set 13 | vestmannaeyjar
# Processing Record 24 of Set 13 | belmonte
# Processing Record 25 of Set 13 | sakaiminato
# Processing Record 26 of Set 13 | ngunguru
# Processing Record 27 of Set 13 | jipijapa
# Processing Record 28 of Set 13 | dingli
# Processing Record 29 of Set 13 | ordzhonikidzevskaya
# Processing Record 30 of Set 13 | peace river
# Processing Record 31 of Set 13 | alice springs
# Processing Record 32 of Set 13 | adela
# Processing Record 33 of Set 13 | zhigansk
# Processing Record 34 of Set 13 | morant bay
# Processing Record 35 of Set 13 | vostok
# Processing Record 36 of Set 13 | olafsvik
# Processing Record 37 of Set 13 | khoy
# Processing Record 38 of Set 13 | bundaberg
# Processing Record 39 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 13 | yantal
# Processing Record 41 of Set 13 | patea
# Processing Record 42 of Set 13 | lewistown
# Processing Record 43 of Set 13 | taoudenni
# Processing Record 44 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 13 | wagrowiec
# Processing Record 46 of Set 13 | dolinsk
# Processing Record 47 of Set 13 | rio gallegos
# Processing Record 48 of Set 13 | sinnamary
# Processing Record 49 of Set 13 | saurimo
# Processing Record 50 of Set 13 | porosozero
# Processing Record 1 of Set 14 | mahad
# Processing Record 2 of Set 14 | itajuba
# Processing Record 3 of Set 14 | oksfjord
# Processing Record 4 of Set 14 | ifanadiana
# Processing Record 5 of Set 14 | dondaicha
# Processing Record 6 of Set 14 | olavarria
# Processing Record 7 of Set 14 | nouadhibou
# Processing Record 8 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 9 of Set 14 | catalina
# Processing Record 10 of Set 14 | horsham
# Processing Record 11 of Set 14 | sijunjung
# Processing Record 12 of Set 14 | bongandanga
# Processing Record 13 of Set 14 | coahuayana
# Processing Record 14 of Set 14 | dickson
# Processing Record 15 of Set 14 | badak
# Processing Record 16 of Set 14 | ust-kulom
# Processing Record 17 of Set 14 | lota
# Processing Record 18 of Set 14 | lop buri
# Processing Record 19 of Set 14 | saint-denis
# Processing Record 20 of Set 14 | erzin
# Processing Record 21 of Set 14 | suozhen
# Processing Record 22 of Set 14 | hualmay
# Processing Record 23 of Set 14 | ciudad bolivar
# Processing Record 24 of Set 14 | lamu
# Processing Record 25 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 14 | yar-sale
# Processing Record 27 of Set 14 | qurayyat
# Processing Record 28 of Set 14 | flinders
# Processing Record 29 of Set 14 | chiredzi
# Processing Record 30 of Set 14 | kinablangan
# Processing Record 31 of Set 14 | krasnoselkup
# Processing Record 32 of Set 14 | opuwo
# Processing Record 33 of Set 14 | namibe
# Processing Record 34 of Set 14 | sfantu gheorghe
# Processing Record 35 of Set 14 | tiszabercel
# Processing Record 36 of Set 14 | te anau
# Processing Record 37 of Set 14 | oranjemund
# Processing Record 38 of Set 14 | mbandaka
# Processing Record 39 of Set 14 | persan
# Processing Record 40 of Set 14 | antalaha
# Processing Record 41 of Set 14 | oranjestad
# Processing Record 42 of Set 14 | shenjiamen
# Processing Record 43 of Set 14 | biltine
# Processing Record 44 of Set 14 | kloulklubed
# Processing Record 45 of Set 14 | taonan
# Processing Record 46 of Set 14 | waverly
# Processing Record 47 of Set 14 | chaumont
# Processing Record 48 of Set 14 | skowhegan
# Processing Record 49 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 14 | dunmore town
# Processing Record 1 of Set 15 | sibolga
# Processing Record 2 of Set 15 | mangrol
# Processing Record 3 of Set 15 | la ronge
# Processing Record 4 of Set 15 | chicama
# Processing Record 5 of Set 15 | fuyang
# Processing Record 6 of Set 15 | normandin
# Processing Record 7 of Set 15 | shimoda
# Processing Record 8 of Set 15 | scarborough
# Processing Record 9 of Set 15 | aswan
# Processing Record 10 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 11 of Set 15 | lampitak
# Processing Record 12 of Set 15 | pundaguitan
# Processing Record 13 of Set 15 | benton harbor
# Processing Record 14 of Set 15 | vera cruz
# Processing Record 15 of Set 15 | ypsonas
# Processing Record 16 of Set 15 | ridgecrest
# Processing Record 17 of Set 15 | muli
# Processing Record 18 of Set 15 | tianpeng
# Processing Record 19 of Set 15 | jabalpur
# Processing Record 20 of Set 15 | trinidad
# Processing Record 21 of Set 15 | middelburg
# Processing Record 22 of Set 15 | dustlik
# Processing Record 23 of Set 15 | talnakh
# Processing Record 24 of Set 15 | mildura
# Processing Record 25 of Set 15 | mwense
# Processing Record 26 of Set 15 | mongoumba
# Processing Record 27 of Set 15 | boyolangu
# Processing Record 28 of Set 15 | mahina
# Processing Record 29 of Set 15 | blackfoot
# Processing Record 30 of Set 15 | bonnyville
# Processing Record 31 of Set 15 | fairbanks
# Processing Record 32 of Set 15 | zanjan
# Processing Record 33 of Set 15 | dalnerechensk
# Processing Record 34 of Set 15 | ust-kuyga
# Processing Record 35 of Set 15 | kara-tyube
# Processing Record 36 of Set 15 | domoni
# Processing Record 37 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 15 | srandakan
# Processing Record 39 of Set 15 | liancheng
# Processing Record 40 of Set 15 | biak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     55.51        76          20
# 1       Rikitea -23.1203 -134.9692     77.95        70          28
# 2       Salalah  17.0151   54.0924     78.89        25           0
# 3    Rio Grande -32.0350  -52.0986     71.71        85          71
# 4       Ushuaia -54.8000  -68.3000     51.46        93         100
# 5       Pitimbu  -7.4706  -34.8086     79.39        76          12
# 6       Sambava -14.2667   50.1667     82.92        66          99
# 7          Lebu -37.6167  -73.6500     54.50        91          39
# 8         Kutum  14.2000   24.6667     56.91        19           0
# 9         Vaini -21.2000 -175.2000     82.56        89          75
#
#    Wind Speed Country Current Description
# 0       20.71      CL          few clouds
# 1        5.59      PF    scattered clouds
# 2       17.27      OM           clear sky
# 3       11.07      BR       broken clouds
# 4       24.16      AR             drizzle
# 5        8.81      BR          few clouds
# 6        5.17      MG     overcast clouds
# 7        9.78      CL    scattered clouds
# 8        6.46      SD           clear sky
# 9        9.22      TO       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     55.51        76          20
# 1       Rikitea      PF -23.1203 -134.9692     77.95        70          28
# 2       Salalah      OM  17.0151   54.0924     78.89        25           0
# 3    Rio Grande      BR -32.0350  -52.0986     71.71        85          71
# 4       Ushuaia      AR -54.8000  -68.3000     51.46        93         100
#
#    Wind Speed Current Description
# 0       20.71          few clouds
# 1        5.59    scattered clouds
# 2       17.27           clear sky
# 3       11.07       broken clouds
# 4       24.16             drizzle

# %%
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
